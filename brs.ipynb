# %%
import pandas as pd
import numpy as np
from sklearn.neighbors import NearestNeighbors
from sklearn.decomposition import TruncatedSVD
from scipy.sparse import csr_matrix
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# 🟢 Load data with specified dtypes to fix DtypeWarning
books = pd.read_csv('books.csv', encoding='latin-1', dtype={
    'ISBN': str,
    'Book-Title': str,
    'Book-Author': str,
    'Year-Of-Publication': str,  # Load as string first to clean
    'Publisher': str,
    'Image-URL-S': str,
    'Image-URL-M': str,
    'Image-URL-L': str
})
ratings = pd.read_csv('ratings.csv', encoding='latin-1', dtype={
    'User-ID': int,
    'ISBN': str,
    'Book-Rating': int
})
users = pd.read_csv('users.csv', encoding='latin-1', dtype={
    'User-ID': int,
    'Location': str,
    'Age': float  # Use float to handle missing values
})

# 🟢 Clean Year-Of-Publication column
books['Year-Of-Publication'] = pd.to_numeric(books['Year-Of-Publication'], errors='coerce')
books.fillna('', inplace=True)

# 🟢 Merge ratings with books
merged_data = pd.merge(ratings, books, on='ISBN')
merged_data.fillna(0, inplace=True)

# 🟢 Filter to reduce size and fix PerformanceWarning
# Only include users who rated at least 20 books and books with at least 50 ratings
filtered_users = merged_data['User-ID'].value_counts()[merged_data['User-ID'].value_counts() >= 20].index
filtered_books = merged_data['Book-Title'].value_counts()[merged_data['Book-Title'].value_counts() >= 50].index
filtered_data = merged_data[merged_data['User-ID'].isin(filtered_users) & merged_data['Book-Title'].isin(filtered_books)]

# 🟢 Create a user-item matrix with a sparse format to save memory
user_item_matrix = filtered_data.pivot_table(index='User-ID', columns='Book-Title', values='Book-Rating', fill_value=0)
sparse_matrix = csr_matrix(user_item_matrix)
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.0.2 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "/Users/gaganphadke/opt/anaconda3/lib/python3.9/runpy.py", line 197, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/Users/gaganphadke/opt/anaconda3/lib/python3.9/runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "/Users/gaganphadke/opt/anaconda3/lib/python3.9/site-packages/ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "/Users/gaganphadke/opt/anaconda3/lib/python3.9/site-packages/traitlets/config/application.py", line 846, in launch_instance
#     app.start()
#   File "/Users/gaganphadke/opt/anaconda3/lib/python3.9/site-packages/ipykernel/kernelapp.py", line 712, in start
#     self.io_loop.start()
#   File "/Users/gaganphadke/opt/anaconda3/lib/python3.9/site-packages/tornado/platform/asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "/Users/gaganphadke/opt/anaconda3/lib/python3.9/asyncio/base_events.py", line 601, in run_forever
#     self._run_once()
#   File "/Users/gaganphadke/opt/anaconda3/lib/python3.9/asyncio/base_events.py", line 1905, in _run_once
#     handle._run()
#   File "/Users/gaganphadke/opt/anaconda3/lib/python3.9/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/Users/gaganphadke/opt/anaconda3/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 510, in dispatch_queue
#     await self.process_one()
#   File "/Users/gaganphadke/opt/anaconda3/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 499, in process_one
#     await dispatch(*args)
#   File "/Users/gaganphadke/opt/anaconda3/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 406, in dispatch_shell
#     await result
#   File "/Users/gaganphadke/opt/anaconda3/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 730, in execute_request
#     reply_content = await reply_content
#   File "/Users/gaganphadke/opt/anaconda3/lib/python3.9/site-packages/ipykernel/ipkernel.py", line 390, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/Users/gaganphadke/opt/anaconda3/lib/python3.9/site-packages/ipykernel/zmqshell.py", line 528, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/Users/gaganphadke/opt/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 2914, in run_cell
#     result = self._run_cell(
#   File "/Users/gaganphadke/opt/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 2960, in _run_cell
#     return runner(coro)
#   File "/Users/gaganphadke/opt/anaconda3/lib/python3.9/site-packages/IPython/core/async_helpers.py", line 78, in _pseudo_sync_runner
#     coro.send(None)
#   File "/Users/gaganphadke/opt/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3185, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/Users/gaganphadke/opt/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3377, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/Users/gaganphadke/opt/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/j9/s4jcytnj6nz1p51h4tmhf2380000gn/T/ipykernel_50680/1603876756.py", line 1, in <module>
#     import pandas as pd
#   File "/Users/gaganphadke/opt/anaconda3/lib/python3.9/site-packages/pandas/__init__.py", line 26, in <module>
#     from pandas.compat import (
#   File "/Users/gaganphadke/opt/anaconda3/lib/python3.9/site-packages/pandas/compat/__init__.py", line 27, in <module>
#     from pandas.compat.pyarrow import (
#   File "/Users/gaganphadke/opt/anaconda3/lib/python3.9/site-packages/pandas/compat/pyarrow.py", line 8, in <module>
#     import pyarrow as pa
#   File "/Users/gaganphadke/opt/anaconda3/lib/python3.9/site-packages/pyarrow/__init__.py", line 65, in <module>
#     import pyarrow.lib as _lib
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: _ARRAY_API not found
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.0.2 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "/Users/gaganphadke/opt/anaconda3/lib/python3.9/runpy.py", line 197, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/Users/gaganphadke/opt/anaconda3/lib/python3.9/runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "/Users/gaganphadke/opt/anaconda3/lib/python3.9/site-packages/ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "/Users/gaganphadke/opt/anaconda3/lib/python3.9/site-packages/traitlets/config/application.py", line 846, in launch_instance
#     app.start()
#   File "/Users/gaganphadke/opt/anaconda3/lib/python3.9/site-packages/ipykernel/kernelapp.py", line 712, in start
#     self.io_loop.start()
#   File "/Users/gaganphadke/opt/anaconda3/lib/python3.9/site-packages/tornado/platform/asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "/Users/gaganphadke/opt/anaconda3/lib/python3.9/asyncio/base_events.py", line 601, in run_forever
#     self._run_once()
#   File "/Users/gaganphadke/opt/anaconda3/lib/python3.9/asyncio/base_events.py", line 1905, in _run_once
#     handle._run()
#   File "/Users/gaganphadke/opt/anaconda3/lib/python3.9/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/Users/gaganphadke/opt/anaconda3/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 510, in dispatch_queue
#     await self.process_one()
#   File "/Users/gaganphadke/opt/anaconda3/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 499, in process_one
#     await dispatch(*args)
#   File "/Users/gaganphadke/opt/anaconda3/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 406, in dispatch_shell
#     await result
#   File "/Users/gaganphadke/opt/anaconda3/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 730, in execute_request
#     reply_content = await reply_content
#   File "/Users/gaganphadke/opt/anaconda3/lib/python3.9/site-packages/ipykernel/ipkernel.py", line 390, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/Users/gaganphadke/opt/anaconda3/lib/python3.9/site-packages/ipykernel/zmqshell.py", line 528, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/Users/gaganphadke/opt/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 2914, in run_cell
#     result = self._run_cell(
#   File "/Users/gaganphadke/opt/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 2960, in _run_cell
#     return runner(coro)
#   File "/Users/gaganphadke/opt/anaconda3/lib/python3.9/site-packages/IPython/core/async_helpers.py", line 78, in _pseudo_sync_runner
#     coro.send(None)
#   File "/Users/gaganphadke/opt/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3185, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/Users/gaganphadke/opt/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3377, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/Users/gaganphadke/opt/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/j9/s4jcytnj6nz1p51h4tmhf2380000gn/T/ipykernel_50680/1603876756.py", line 1, in <module>
#     import pandas as pd
#   File "/Users/gaganphadke/opt/anaconda3/lib/python3.9/site-packages/pandas/__init__.py", line 49, in <module>
#     from pandas.core.api import (
#   File "/Users/gaganphadke/opt/anaconda3/lib/python3.9/site-packages/pandas/core/api.py", line 9, in <module>
#     from pandas.core.dtypes.dtypes import (
#   File "/Users/gaganphadke/opt/anaconda3/lib/python3.9/site-packages/pandas/core/dtypes/dtypes.py", line 24, in <module>
#     from pandas._libs import (
#   File "/Users/gaganphadke/opt/anaconda3/lib/python3.9/site-packages/pyarrow/__init__.py", line 65, in <module>
#     import pyarrow.lib as _lib
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: _ARRAY_API not found
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.0.2 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "/Users/gaganphadke/opt/anaconda3/lib/python3.9/runpy.py", line 197, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/Users/gaganphadke/opt/anaconda3/lib/python3.9/runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "/Users/gaganphadke/opt/anaconda3/lib/python3.9/site-packages/ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "/Users/gaganphadke/opt/anaconda3/lib/python3.9/site-packages/traitlets/config/application.py", line 846, in launch_instance
#     app.start()
#   File "/Users/gaganphadke/opt/anaconda3/lib/python3.9/site-packages/ipykernel/kernelapp.py", line 712, in start
#     self.io_loop.start()
#   File "/Users/gaganphadke/opt/anaconda3/lib/python3.9/site-packages/tornado/platform/asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "/Users/gaganphadke/opt/anaconda3/lib/python3.9/asyncio/base_events.py", line 601, in run_forever
#     self._run_once()
#   File "/Users/gaganphadke/opt/anaconda3/lib/python3.9/asyncio/base_events.py", line 1905, in _run_once
#     handle._run()
#   File "/Users/gaganphadke/opt/anaconda3/lib/python3.9/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/Users/gaganphadke/opt/anaconda3/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 510, in dispatch_queue
#     await self.process_one()
#   File "/Users/gaganphadke/opt/anaconda3/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 499, in process_one
#     await dispatch(*args)
#   File "/Users/gaganphadke/opt/anaconda3/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 406, in dispatch_shell
#     await result
#   File "/Users/gaganphadke/opt/anaconda3/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 730, in execute_request
#     reply_content = await reply_content
#   File "/Users/gaganphadke/opt/anaconda3/lib/python3.9/site-packages/ipykernel/ipkernel.py", line 390, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/Users/gaganphadke/opt/anaconda3/lib/python3.9/site-packages/ipykernel/zmqshell.py", line 528, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/Users/gaganphadke/opt/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 2914, in run_cell
#     result = self._run_cell(
#   File "/Users/gaganphadke/opt/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 2960, in _run_cell
#     return runner(coro)
#   File "/Users/gaganphadke/opt/anaconda3/lib/python3.9/site-packages/IPython/core/async_helpers.py", line 78, in _pseudo_sync_runner
#     coro.send(None)
#   File "/Users/gaganphadke/opt/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3185, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/Users/gaganphadke/opt/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3377, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/Users/gaganphadke/opt/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/j9/s4jcytnj6nz1p51h4tmhf2380000gn/T/ipykernel_50680/1603876756.py", line 1, in <module>
#     import pandas as pd
#   File "/Users/gaganphadke/opt/anaconda3/lib/python3.9/site-packages/pandas/__init__.py", line 49, in <module>
#     from pandas.core.api import (
#   File "/Users/gaganphadke/opt/anaconda3/lib/python3.9/site-packages/pandas/core/api.py", line 28, in <module>
#     from pandas.core.arrays import Categorical
#   File "/Users/gaganphadke/opt/anaconda3/lib/python3.9/site-packages/pandas/core/arrays/__init__.py", line 1, in <module>
#     from pandas.core.arrays.arrow import ArrowExtensionArray
#   File "/Users/gaganphadke/opt/anaconda3/lib/python3.9/site-packages/pandas/core/arrays/arrow/__init__.py", line 5, in <module>
#     from pandas.core.arrays.arrow.array import ArrowExtensionArray
#   File "/Users/gaganphadke/opt/anaconda3/lib/python3.9/site-packages/pandas/core/arrays/arrow/array.py", line 50, in <module>
#     from pandas.core import (
#   File "/Users/gaganphadke/opt/anaconda3/lib/python3.9/site-packages/pandas/core/ops/__init__.py", line 8, in <module>
#     from pandas.core.ops.array_ops import (
#   File "/Users/gaganphadke/opt/anaconda3/lib/python3.9/site-packages/pandas/core/ops/array_ops.py", line 56, in <module>
#     from pandas.core.computation import expressions
#   File "/Users/gaganphadke/opt/anaconda3/lib/python3.9/site-packages/pandas/core/computation/expressions.py", line 21, in <module>
#     from pandas.core.computation.check import NUMEXPR_INSTALLED
#   File "/Users/gaganphadke/opt/anaconda3/lib/python3.9/site-packages/pandas/core/computation/check.py", line 5, in <module>
#     ne = import_optional_dependency("numexpr", errors="warn")
#   File "/Users/gaganphadke/opt/anaconda3/lib/python3.9/site-packages/pandas/compat/_optional.py", line 135, in import_optional_dependency
#     module = importlib.import_module(name)
#   File "/Users/gaganphadke/opt/anaconda3/lib/python3.9/importlib/__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "/Users/gaganphadke/opt/anaconda3/lib/python3.9/site-packages/numexpr/__init__.py", line 24, in <module>
#     from numexpr.interpreter import MAX_THREADS, use_vml, __BLOCK_SIZE1__
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: _ARRAY_API not found
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.0.2 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "/Users/gaganphadke/opt/anaconda3/lib/python3.9/runpy.py", line 197, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/Users/gaganphadke/opt/anaconda3/lib/python3.9/runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "/Users/gaganphadke/opt/anaconda3/lib/python3.9/site-packages/ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "/Users/gaganphadke/opt/anaconda3/lib/python3.9/site-packages/traitlets/config/application.py", line 846, in launch_instance
#     app.start()
#   File "/Users/gaganphadke/opt/anaconda3/lib/python3.9/site-packages/ipykernel/kernelapp.py", line 712, in start
#     self.io_loop.start()
#   File "/Users/gaganphadke/opt/anaconda3/lib/python3.9/site-packages/tornado/platform/asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "/Users/gaganphadke/opt/anaconda3/lib/python3.9/asyncio/base_events.py", line 601, in run_forever
#     self._run_once()
#   File "/Users/gaganphadke/opt/anaconda3/lib/python3.9/asyncio/base_events.py", line 1905, in _run_once
#     handle._run()
#   File "/Users/gaganphadke/opt/anaconda3/lib/python3.9/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/Users/gaganphadke/opt/anaconda3/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 510, in dispatch_queue
#     await self.process_one()
#   File "/Users/gaganphadke/opt/anaconda3/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 499, in process_one
#     await dispatch(*args)
#   File "/Users/gaganphadke/opt/anaconda3/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 406, in dispatch_shell
#     await result
#   File "/Users/gaganphadke/opt/anaconda3/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 730, in execute_request
#     reply_content = await reply_content
#   File "/Users/gaganphadke/opt/anaconda3/lib/python3.9/site-packages/ipykernel/ipkernel.py", line 390, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/Users/gaganphadke/opt/anaconda3/lib/python3.9/site-packages/ipykernel/zmqshell.py", line 528, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/Users/gaganphadke/opt/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 2914, in run_cell
#     result = self._run_cell(
#   File "/Users/gaganphadke/opt/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 2960, in _run_cell
#     return runner(coro)
#   File "/Users/gaganphadke/opt/anaconda3/lib/python3.9/site-packages/IPython/core/async_helpers.py", line 78, in _pseudo_sync_runner
#     coro.send(None)
#   File "/Users/gaganphadke/opt/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3185, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/Users/gaganphadke/opt/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3377, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/Users/gaganphadke/opt/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/j9/s4jcytnj6nz1p51h4tmhf2380000gn/T/ipykernel_50680/1603876756.py", line 1, in <module>
#     import pandas as pd
#   File "/Users/gaganphadke/opt/anaconda3/lib/python3.9/site-packages/pandas/__init__.py", line 49, in <module>
#     from pandas.core.api import (
#   File "/Users/gaganphadke/opt/anaconda3/lib/python3.9/site-packages/pandas/core/api.py", line 28, in <module>
#     from pandas.core.arrays import Categorical
#   File "/Users/gaganphadke/opt/anaconda3/lib/python3.9/site-packages/pandas/core/arrays/__init__.py", line 1, in <module>
#     from pandas.core.arrays.arrow import ArrowExtensionArray
#   File "/Users/gaganphadke/opt/anaconda3/lib/python3.9/site-packages/pandas/core/arrays/arrow/__init__.py", line 5, in <module>
#     from pandas.core.arrays.arrow.array import ArrowExtensionArray
#   File "/Users/gaganphadke/opt/anaconda3/lib/python3.9/site-packages/pandas/core/arrays/arrow/array.py", line 64, in <module>
#     from pandas.core.arrays.masked import BaseMaskedArray
#   File "/Users/gaganphadke/opt/anaconda3/lib/python3.9/site-packages/pandas/core/arrays/masked.py", line 60, in <module>
#     from pandas.core import (
#   File "/Users/gaganphadke/opt/anaconda3/lib/python3.9/site-packages/pandas/core/nanops.py", line 52, in <module>
#     bn = import_optional_dependency("bottleneck", errors="warn")
#   File "/Users/gaganphadke/opt/anaconda3/lib/python3.9/site-packages/pandas/compat/_optional.py", line 135, in import_optional_dependency
#     module = importlib.import_module(name)
#   File "/Users/gaganphadke/opt/anaconda3/lib/python3.9/importlib/__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "/Users/gaganphadke/opt/anaconda3/lib/python3.9/site-packages/bottleneck/__init__.py", line 7, in <module>
#     from .move import (move_argmax, move_argmin, move_max, move_mean, move_median,
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: _ARRAY_API not found
# /var/folders/j9/s4jcytnj6nz1p51h4tmhf2380000gn/T/ipykernel_50680/1603876756.py:33: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   books.fillna('', inplace=True)

# %%
# 🟢 Print all unique user IDs in the new matrix
print("All User IDs in the filtered user-item matrix:")
print(user_item_matrix.index.tolist())
# Out:
# All User IDs in the filtered user-item matrix:
# [242, 243, 254, 383, 388, 408, 446, 487, 503, 507, 638, 643, 651, 709, 728, 735, 741, 805, 882, 901, 929, 1025, 1131, 1211, 1248, 1424, 1435, 1548, 1674, 1733, 1848, 1903, 1928, 2010, 2012, 2030, 2033, 2046, 2090, 2110, 2132, 2179, 2276, 2288, 2313, 2358, 2363, 2719, 2766, 2793, 2891, 2954, 2977, 3145, 3167, 3282, 3346, 3363, 3371, 3373, 3538, 3556, 3675, 3757, 3827, 3840, 3915, 3917, 3923, 4017, 4092, 4114, 4131, 4157, 4197, 4223, 4334, 4385, 4401, 4600, 4622, 4785, 4896, 4938, 5037, 5209, 5331, 5350, 5385, 5439, 5476, 5483, 5499, 5539, 5543, 5582, 5609, 5694, 5709, 5899, 5903, 5956, 6007, 6073, 6120, 6238, 6242, 6251, 6280, 6323, 6333, 6345, 6366, 6431, 6432, 6532, 6537, 6543, 6563, 6564, 6575, 6577, 6611, 6662, 6731, 6772, 6789, 6866, 6900, 7082, 7105, 7125, 7128, 7134, 7158, 7210, 7283, 7286, 7312, 7346, 7371, 7569, 7620, 7841, 7864, 7887, 7915, 7958, 8019, 8066, 8067, 8167, 8234, 8245, 8250, 8253, 8284, 8314, 8362, 8454, 8487, 8529, 8584, 8672, 8680, 8681, 8695, 8734, 8782, 8801, 8839, 8870, 8872, 8890, 8936, 8937, 8971, 9029, 9141, 9227, 9289, 9354, 9357, 9381, 9408, 9417, 9571, 9613, 9660, 9747, 9856, 9908, 10001, 10030, 10067, 10118, 10199, 10241, 10314, 10354, 10447, 10560, 10590, 10716, 10819, 11120, 11224, 11245, 11400, 11601, 11629, 11657, 11676, 11687, 11690, 11709, 11718, 11724, 11817, 11832, 11944, 11993, 12100, 12112, 12154, 12189, 12194, 12238, 12272, 12331, 12515, 12537, 12538, 12569, 12692, 12811, 12824, 12835, 12863, 12917, 12982, 12990, 13080, 13082, 13093, 13173, 13273, 13279, 13280, 13518, 13540, 13551, 13552, 13582, 13600, 13607, 13664, 13666, 13850, 13935, 13995, 14079, 14173, 14180, 14230, 14232, 14326, 14374, 14387, 14422, 14449, 14451, 14456, 14461, 14521, 14638, 14667, 14698, 14744, 14768, 14897, 14966, 15021, 15049, 15076, 15093, 15135, 15208, 15408, 15418, 15497, 15589, 15602, 15651, 15670, 15819, 15918, 15945, 15957, 16005, 16009, 16036, 16106, 16121, 16155, 16161, 16237, 16246, 16263, 16413, 16417, 16488, 16504, 16545, 16599, 16601, 16634, 16718, 16721, 16759, 16777, 16781, 16795, 16835, 16871, 16877, 16908, 16916, 16943, 16949, 16966, 16996, 16999, 17003, 17183, 17190, 17282, 17391, 17507, 17645, 17667, 17761, 17859, 17894, 17950, 17970, 18038, 18067, 18082, 18095, 18096, 18155, 18167, 18172, 18250, 18254, 18309, 18322, 18323, 18384, 18401, 18439, 18519, 18714, 18850, 18979, 18995, 19018, 19022, 19085, 19145, 19220, 19233, 19336, 19422, 19493, 19522, 19570, 19605, 19664, 19681, 19695, 19711, 19753, 19760, 19842, 19969, 19972, 20060, 20115, 20119, 20149, 20172, 20180, 20201, 20265, 20332, 20336, 20347, 20409, 20448, 20462, 20561, 20627, 20846, 20851, 20859, 20961, 20971, 21011, 21014, 21031, 21049, 21116, 21155, 21202, 21229, 21231, 21252, 21343, 21356, 21364, 21370, 21404, 21484, 21540, 21576, 21618, 21659, 21708, 21774, 21860, 21875, 22022, 22023, 22045, 22062, 22074, 22089, 22107, 22154, 22200, 22252, 22365, 22409, 22495, 22521, 22547, 22624, 22625, 22710, 22818, 22885, 22900, 22981, 23065, 23124, 23288, 23408, 23511, 23547, 23571, 23619, 23631, 23652, 23659, 23680, 23699, 23768, 23771, 23871, 23872, 23902, 23933, 23997, 24186, 24188, 24194, 24379, 24391, 24433, 24452, 24462, 24539, 24544, 24627, 24641, 24694, 24733, 24778, 24835, 24838, 24846, 24878, 24921, 24933, 24934, 24941, 24945, 25009, 25131, 25253, 25261, 25311, 25359, 25395, 25409, 25410, 25436, 25466, 25533, 25583, 25601, 25630, 25695, 25700, 25792, 25804, 25827, 25850, 25890, 25916, 25919, 25930, 25966, 25981, 26057, 26084, 26133, 26153, 26182, 26196, 26231, 26240, 26346, 26371, 26443, 26487, 26516, 26517, 26535, 26538, 26544, 26583, 26593, 26598, 26620, 26621, 26624, 26711, 26713, 26730, 26756, 26813, 26831, 26883, 26949, 27091, 27140, 27169, 27193, 27363, 27383, 27462, 27472, 27551, 27617, 27647, 27650, 27740, 27788, 27812, 27813, 27875, 27947, 28016, 28076, 28139, 28177, 28204, 28222, 28255, 28360, 28451, 28454, 28488, 28492, 28523, 28591, 28594, 28602, 28619, 28634, 28663, 28666, 28667, 28735, 28820, 28865, 28877, 28938, 29000 ...

# %%
# 🟢 KNN model for collaborative filtering
model_knn = NearestNeighbors(metric='cosine', algorithm='brute', n_neighbors=6)
model_knn.fit(sparse_matrix)

# 🟢 SVD for matrix factorization with optimized components
svd = TruncatedSVD(n_components=20)
svd_matrix = svd.fit_transform(sparse_matrix)

# 🟢 KNN Recommendations
def get_knn_recommendations(user_id, num_recommendations=5):
    if user_id not in user_item_matrix.index:
        return ["User ID not found."]
    user_index = user_item_matrix.index.get_loc(user_id)
    distances, indices = model_knn.kneighbors(sparse_matrix[user_index], n_neighbors=num_recommendations + 1)
   # 🟢 Fix for IndexError: Use valid column indices only
    recommendations = [
    user_item_matrix.columns[i] for i in indices.flatten() if i < len(user_item_matrix.columns)
][1:]

    return recommendations

# 🟢 SVD Recommendations
def get_svd_recommendations(user_id, num_recommendations=5):
    if user_id not in user_item_matrix.index:
        return ["User ID not found."]
    user_index = user_item_matrix.index.get_loc(user_id)
    user_vector = svd_matrix[user_index].reshape(1, -1)
    scores = svd_matrix.dot(user_vector.T).flatten()
    top_indices = scores.argsort()[-num_recommendations - 1:][::-1]
    recommendations = [
    user_item_matrix.columns[i] for i in top_indices 
    if i != user_index and i < len(user_item_matrix.columns)
]

    return recommendations

# 🟢 Test Recommendations
print("KNN Recommendations for User 95932:")
print(get_knn_recommendations(95932))

print("\nSVD Recommendations for User 95932:")
print(get_svd_recommendations(95932))
# Out:
# KNN Recommendations for User 95932:
# ['Beneath the Skin', 'The Vagina Monologues: The V-Day Edition', 'Lost in a Good Book: A Thursday Next Novel']
#
# SVD Recommendations for User 95932:
# ["Band of Brothers : E Company, 506th Regiment, 101st Airborne from Normandy to Hitler's Eagle's Nest", 'The Tailor of Panama', 'Pot Shot']

# %%
# Combine book descriptions and authors for NLP with .fillna() to handle missing values
books['Content'] = books['Book-Title'].fillna('') + ' ' + books['Book-Author'].fillna('')

# TF-IDF Vectorization with reduced max_features to save memory
tfidf = TfidfVectorizer(stop_words='english', max_features=500)  # Reduced to 500 to prevent crashes
tfidf_matrix = tfidf.fit_transform(books['Content']).astype('float32')  # Use float32 to save memory

# Compute Cosine Similarity as sparse matrix to save memory
cosine_sim = cosine_similarity(tfidf_matrix, dense_output=False)


# Content-Based Recommendations
def get_content_based_recommendations(title, num_recommendations=5):
    if title not in books['Book-Title'].values:
        return ["Book title not found."]
    idx = books[books['Book-Title'] == title].index[0]
    sim_scores = list(enumerate(cosine_sim[idx]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    book_indices = [i[0] for i in sim_scores[1:num_recommendations + 1]]
    return books['Book-Title'].iloc[book_indices].tolist()

# %%
# User Profile Creation
def get_user_profile(user_id):
    if user_id not in ratings['User-ID'].values:
        return {"Error": "User ID not found."}
    user_ratings = merged_data[merged_data['User-ID'] == user_id]
    profile = {
        'Books Read': len(user_ratings),
        'Average Rating Given': user_ratings['Book-Rating'].mean(),
        'Top Genres': user_ratings['Book-Title'].value_counts().head(5).index.tolist()
    }
    return profile

# Example of getting a user profile
print("User Profile for 95932:")
print(get_user_profile(95932))
# Out:
# User Profile for 95932:
# {'Books Read': 459, 'Average Rating Given': np.float64(2.3769063180827885), 'Top Genres': ['The Prince of Tides', 'Daughters of the Moon', "Julian's House", 'Calypso Dreaming', "Summoning the Fates: A Woman's Guide to Destiny"]}

# %%
# Feedback Loop: Ratings & Like/Dislike
user_feedback = {}  # Dictionary to store feedback

def give_feedback(user_id, book_title, rating):
    if user_id not in user_item_matrix.index or book_title not in user_item_matrix.columns:
        return "Invalid user ID or book title."
    user_feedback[(user_id, book_title)] = rating
    # Update user-item matrix
    user_item_matrix.loc[user_id, book_title] = rating
    return "Feedback recorded!"

# Example Usage of Feedback
print(give_feedback(95932, 'The Da Vinci Code', 5))
# Out:
# Feedback recorded!

# %%
# Collaborative Recommendations
print("KNN Recommendations for User 95932:")
print(get_knn_recommendations(95932))

print("\nSVD Recommendations for User 95932:")
print(get_svd_recommendations(95932))

# Content-Based Recommendations
print("\nContent-Based Recommendations for 'The Da Vinci Code':")
print(get_content_based_recommendations('The Da Vinci Code'))

# User Profile
print("\nUser Profile for 95932:")
print(get_user_profile(95932))

# Feedback Example
print("\nFeedback for 'The Da Vinci Code':")
print(give_feedback(95932, 'The Da Vinci Code', 5))
# Out:
# KNN Recommendations for User 95932:
# ['Beneath the Skin', 'The Vagina Monologues: The V-Day Edition', 'Lost in a Good Book: A Thursday Next Novel']
#
# SVD Recommendations for User 95932:
# ["Band of Brothers : E Company, 506th Regiment, 101st Airborne from Normandy to Hitler's Eagle's Nest", 'The Tailor of Panama', 'Pot Shot']
#
# Content-Based Recommendations for 'The Da Vinci Code':
# []
#
# User Profile for 95932:
# {'Books Read': 459, 'Average Rating Given': np.float64(2.3769063180827885), 'Top Genres': ['The Prince of Tides', 'Daughters of the Moon', "Julian's House", 'Calypso Dreaming', "Summoning the Fates: A Woman's Guide to Destiny"]}
#
# Feedback for 'The Da Vinci Code':
# Feedback recorded!

# %%
! pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in /Users/gaganphadke/opt/anaconda3/lib/python3.9/site-packages (3.9.4)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/gaganphadke/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/gaganphadke/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/gaganphadke/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (1.4.2)
# Requirement already satisfied: numpy>=1.23 in /Users/gaganphadke/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (2.0.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/gaganphadke/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (6.4.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/gaganphadke/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/gaganphadke/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in /Users/gaganphadke/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (21.3)
# Requirement already satisfied: cycler>=0.10 in /Users/gaganphadke/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: pillow>=8 in /Users/gaganphadke/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (9.2.0)
# Requirement already satisfied: zipp>=3.1.0 in /Users/gaganphadke/opt/anaconda3/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib) (3.8.0)
# Requirement already satisfied: six>=1.5 in /Users/gaganphadke/opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# WARNING: There was an error checking the latest version of pip.

# %%
# 🟢 Plot rating distribution
import matplotlib.pyplot as plt
plt.hist(merged_data['Book-Rating'], bins=10, color='skyblue', edgecolor='black')
plt.title('Rating Distribution')
plt.xlabel('Rating')
plt.ylabel('Frequency')
plt.grid(axis='y', linestyle='--')
plt.show()

# %%
# 🟢 Most read authors
most_read_authors = merged_data['Book-Author'].value_counts().head(5)
most_read_authors.plot(kind='bar', title='Most Read Authors', color='orange')
plt.xlabel('Author')
plt.ylabel('Read Count')
plt.grid(axis='y', linestyle='--')
plt.show()

# %%
# 🟢 Most rated books
top_rated_books = merged_data.groupby('Book-Title')['Book-Rating'].mean().sort_values(ascending=False).head(5)
top_rated_books.plot(kind='bar', title='Top Rated Books', color='green')
plt.xlabel('Book Title')
plt.ylabel('Average Rating')
plt.grid(axis='y', linestyle='--')
plt.show()

# %%
user_id = 95932  # Example User ID
print(f"\n🔹 Similar books based on user preferences (KNN) for User {user_id}:")
knn_recs = get_knn_recommendations(user_id)
for i, book in enumerate(knn_recs, 1):
    print(f"{i}. {book}")

# 🟢 Print SVD-based Recommendations
print(f"\n🔹 Similar books based on user preferences (SVD) for User {user_id}:")
svd_recs = get_svd_recommendations(user_id)
for i, book in enumerate(svd_recs, 1):
    print(f"{i}. {book}")

# 🟢 Print Content-Based Recommendations using TF-IDF
book_title = 'The Da Vinci Code'  # Example Book Title
print(f"\n🔹 Books with similar content to '{book_title}' (Content-Based using TF-IDF):")
content_recs = get_content_based_recommendations(book_title)
for i, book in enumerate(content_recs, 1):
    print(f"{i}. {book}")
# Out:
# 🔹 Similar books based on user preferences (KNN) for User 243:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/j9/s4jcytnj6nz1p51h4tmhf2380000gn/T/ipykernel_52802/1258583293.py in <module>
#       1 user_id = 243  # Example User ID
#       2 print(f"\n🔹 Similar books based on user preferences (KNN) for User {user_id}:")
# ----> 3 knn_recs = get_knn_recommendations(user_id)
#       4 for i, book in enumerate(knn_recs, 1):
#       5     print(f"{i}. {book}")
#
# NameError: name 'get_knn_recommendations' is not defined
